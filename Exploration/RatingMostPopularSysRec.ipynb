# %%
import pandas as pd
import numpy as np
from textblob import TextBlob

df = pd.read_csv("reviews_filtered.csv")
df.head()

df["sentiment"] = df["Review"].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
def getRecommendationMostPopularSimple(df: pd.DataFrame):
    copy_df = df.copy()
    copy_df = copy_df.sort_values("Rating", ascending=False)
    return copy_df

def getRecommendationMostPopularPolarity(df: pd.DataFrame, rating_weight: float,
                                         sentiment_weight: float):
    copy_df = df.copy()
    copy_df["wr"] = copy_df["Rating"] * rating_weight + copy_df["sentiment"] * sentiment_weight
    copy_df = copy_df.sort_values("wr", ascending=False)
    return copy_df


getRecommendationMostPopularPolarity(df, 0.6, 0.4)
# Out:
#       ReviewId  RecipeId  AuthorId      AuthorName  Rating  \
# 4009   1429171     10125     26517           Ann S       5
# 2410      4633      8462     21730     Izzy Knight       5
# 2366      4580      3549     21694    LikeItLoveIt       5
# 2364      4578     12683     21694    LikeItLoveIt       5
# 2359      4572     11173     21694    LikeItLoveIt       5
# ...        ...       ...       ...             ...     ...
# 2248      4440      8665     10332  chris brossard       0
# 2542      4804      1024     22132          EILEEN       0
# 911       1454      6649     12038        Lesa1181       0
# 1761      3708      9313     10332  chris brossard       0
# 55         109      2505      3287       Amy Hayes       0
#
#                                                  Review  \
# 4009                                        Wonderful!!
# 2410  Delicious. I substitued onions with shallots a...
# 2366  Very delicious, I will have to make this at Ch...
# ...
